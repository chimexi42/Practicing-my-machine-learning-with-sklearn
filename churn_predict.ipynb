# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.sample(8)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4923  6075-QMNRR  Female              0      No         No      52
# 3881  2176-OSJUV    Male              0     Yes         No      71
# 5772  8645-KOMJQ    Male              0     Yes        Yes      69
# 2086  2955-BJZHG    Male              0     Yes        Yes      17
# 429   6152-ONASV  Female              0     Yes         No      68
# 5798  4548-SDBKE  Female              0      No         No       5
# 5522  2619-WFQWU  Female              0      No         No       1
# 907   0297-RBCSG    Male              0      No         No      19
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 4923          Yes            No             DSL            Yes  ...
# 3881          Yes           Yes             DSL            Yes  ...
# 5772          Yes           Yes             DSL             No  ...
# 2086          Yes            No     Fiber optic             No  ...
# ...

# %%
(df
.query('MonthlyCharges < 100')
.filter(['echSupport',	'StreamingTV',	'StreamingMovies','	Contrac','PaperlessBilling','	PaymentMethod','MonthlyCharges'])
.sort_values(['MonthlyCharges'], ascending = False)

)
# Out:
#               StreamingTV      StreamingMovies PaperlessBilling  \
# 5741                  Yes                  Yes              Yes
# 1962                  Yes                  Yes              Yes
# 1434                  Yes                  Yes              Yes
# 2444                  Yes                  Yes              Yes
# 4921                  Yes                  Yes              Yes
# ...                   ...                  ...              ...
# 6906  No internet service  No internet service              Yes
# 1156  No internet service  No internet service               No
# 6652  No internet service  No internet service              Yes
# 1529  No internet service  No internet service               No
# 3719  No internet service  No internet service               No
#
#       MonthlyCharges
# 5741           99.95
# 1962           99.95
# 1434           99.95
# 2444           99.95
# 4921           99.95
# ...              ...
# 6906           18.70
# ...

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.TotalCharges.values
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %%
pd.to_numeric('df.TotalCharges', errors='coerce')
# Out:
# nan

# %%
pd.to_numeric('df.TotalCharges', errors='coerce').isnull()

# %%
df[pd.to_numeric('df.TotalCharges', errors='coerce').isnull()]

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.corr()
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges
# SeniorCitizen        1.000000  0.016567        0.220173
# tenure               0.016567  1.000000        0.247900
# MonthlyCharges       0.220173  0.247900        1.000000

# %%
df.iloc[488]['TotalCharges']
# Out:
# ' '

# %%
df1 = df[df.TotalCharges != ' ']
df1.shape
# Out:
# (7032, 21)

# %%
df1.TotalCharges=pd.to_numeric(df1.TotalCharges)
# Out:
# C:\Users\Okoro Chima\AppData\Local\Temp\ipykernel_9672\695980592.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.TotalCharges=pd.to_numeric(df1.TotalCharges)

# %%
df1.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
 df1.TotalCharges.dtypes
# Out:
# dtype('float64')

# %%
df[df['Churn' ]== 'No']
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 3     7795-CFOCW    Male              0      No         No      45
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# ...          ...     ...            ...     ...        ...     ...
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0              No  No phone service             DSL                   No  ...
# ...

# %%
tenure_churn_no = df[df['Churn' ]== 'No'].tenure
tenure_churn_yes = df[df['Churn' ]== 'Yes'].tenure


len(tenure_churn_no)
# Out:
# 5174

# %%
len(tenure_churn_yes)
# Out:
# 1869

# %%
tenure_churn_no = df[df['Churn' ]== 'No'].tenure
tenure_churn_yes = df[df['Churn' ]== 'Yes'].tenure

plt.figure(figsize =(12,7))
plt.hist([tenure_churn_yes, tenure_churn_no], color =['green', 'red'], label =['ChurnYes', 'ChurnNo'])
plt.legend()
plt.xlabel('Tenure')
plt.ylabel('Number of cutomers')
plt.title('Customer churn Prediction')
# Out:
# Text(0.5, 1.0, 'Customer churn Prediction')

# %%
mc_churn_no = df[df['Churn' ]== 'No'].MonthlyCharges
mc_churn_yes = df[df['Churn' ]== 'Yes'].MonthlyCharges

plt.figure(figsize =(12,7))
plt.hist([mc_churn_yes,mc_churn_no], color =['green', 'red'], label =['ChurnYes', 'ChurnNo'])
plt.legend()
plt.xlabel('Monthly Charges')
plt.ylabel('Number of cutomers')
plt.title('Customer churn Prediction')
# Out:
# Text(0.5, 1.0, 'Customer churn Prediction')

# %%
def print_unique_columns(df):
    for column in df:
        if df[column].dtypes == 'object':
             print(f'{column}: {df[column].unique()}')

  
print_unique_columns(df1)
# Out:
# customerID: ['7590-VHVEG' '5575-GNVDE' '3668-QPYBK' ... '4801-JZAZL' '8361-LTMKD'
#  '3186-AJIEK']
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['No' 'Yes' 'No internet service']
# StreamingTV: ['No' 'Yes' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %%
# arr = [1,2,3,4,5,6]

# a,b, *c = arr
# print(c)

# print(len(df[column].unique()))

# %%
df1.replace('No internet service', 'No', inplace = True)
df1.replace('No Phone service', 'No', inplace = True)
# Out:
# C:\Users\Okoro Chima\AppData\Local\Temp\ipykernel_9672\3938084411.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No internet service', 'No', inplace = True)
# C:\Users\Okoro Chima\AppData\Local\Temp\ipykernel_9672\3938084411.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('No Phone service', 'No', inplace = True)

# %%
print_unique_columns(df1)
# Out:
# customerID: ['7590-VHVEG' '5575-GNVDE' '3668-QPYBK' ... '4801-JZAZL' '8361-LTMKD'
#  '3186-AJIEK']
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes']
# OnlineBackup: ['Yes' 'No']
# DeviceProtection: ['No' 'Yes']
# TechSupport: ['No' 'Yes']
# StreamingTV: ['No' 'Yes']
# StreamingMovies: ['No' 'Yes']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']
