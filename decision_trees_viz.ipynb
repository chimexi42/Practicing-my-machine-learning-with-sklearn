# %%
from sklearn.datasets import *
from sklearn import tree
import dtreeviz
from dtreeviz.trees import *

# %%
# regr = tree.DecisionTreeRegressor(max_depth =2)
# boston = load_boston()

# regr.fit(boston.data, boston.target)

# viz = dtreeviz(regr, 
#                 boston.data, 
#                 boston.target,
#                 target_name = 'price' ,
#                 feature_names = boston.feature_names,    )
# viz.view()

# %%
# import graphviz  # doctest: +NO_EXE
# graphviz.Digraph(comment='The Round Table')
#doctest: +ELLIPSIS
# <graphviz.graphs.Digraph object at 0x...>

# %%
from sklearn.datasets import load_iris
from sklearn import tree
iris = load_iris()
X, y = iris.data, iris.target
clf = tree.DecisionTreeClassifier(max_depth=3)
clf = clf.fit(X, y)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize =(12,7))
tree.plot_tree(clf)
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_text

iris = load_iris()
decision_tree = DecisionTreeClassifier(random_state=0, max_depth=2)
decision_tree = decision_tree.fit(iris.data, iris.target)
r = export_text(decision_tree, feature_names=iris.feature_names)

print(r)
decision_tree.score(iris.data, iris.target)
# Out:
# |--- petal width (cm) <= 0.80
# |   |--- class: 0
# |--- petal width (cm) >  0.80
# |   |--- petal width (cm) <= 1.75
# |   |   |--- class: 1
# |   |--- petal width (cm) >  1.75
# |   |   |--- class: 2
# 0.96

# %%
from sklearn import tree
X = [[0, 0], [2, 2]]
y = [0.5, 2.5]
clf = tree.DecisionTreeRegressor()
clf = clf.fit(X, y)
clf.predict([[1, 1]])
# Out:
# array([0.5])

# %%
clf.score(X,y)
# Out:
# 1.0

# %%
import pandas as pd
import numpy as np

# %%
sales_data = pd.DataFrame({"name":["William","Emma","Sofia","Markus","Edward","Thomas","Ethan","Olivia","Arun","Anika","Paulo"]
,"region":["East",'N',"East","South","West","West","S","West","West","East","South"]
,"sales":[50000,52000,90000,-1,42000,72000,49000,-1,67000,65000,67000]
,"expenses":[42000,43000,-999,44000,38000,39000,42000,-1,39000,44000,45000]})

# %%
sales_data
# Out:
#        name region  sales  expenses
# 0   William   East  50000     42000
# 1      Emma      N  52000     43000
# 2     Sofia   East  90000      -999
# 3    Markus  South     -1     44000
# 4    Edward   West  42000     38000
# 5    Thomas   West  72000     39000
# 6     Ethan      S  49000     42000
# 7    Olivia   West     -1        -1
# 8      Arun   West  67000     39000
# 9     Anika   East  65000     44000
# 10    Paulo  South  67000     45000

# %%
sales_data.replace([-1, -999], np.NaN)
# Out:
#        name region    sales  expenses
# 0   William   East  50000.0   42000.0
# 1      Emma      N  52000.0   43000.0
# 2     Sofia   East  90000.0       NaN
# 3    Markus  South      NaN   44000.0
# 4    Edward   West  42000.0   38000.0
# 5    Thomas   West  72000.0   39000.0
# 6     Ethan      S  49000.0   42000.0
# 7    Olivia   West      NaN       NaN
# 8      Arun   West  67000.0   39000.0
# 9     Anika   East  65000.0   44000.0
# 10    Paulo  South  67000.0   45000.0

# %%
sales_data.replace(to_replace = -1, value = np.NaN)
# Out:
#        name region    sales  expenses
# 0   William   East  50000.0   42000.0
# 1      Emma      N  52000.0   43000.0
# 2     Sofia   East  90000.0    -999.0
# 3    Markus  South      NaN   44000.0
# 4    Edward   West  42000.0   38000.0
# 5    Thomas   West  72000.0   39000.0
# 6     Ethan      S  49000.0   42000.0
# 7    Olivia   West      NaN       NaN
# 8      Arun   West  67000.0   39000.0
# 9     Anika   East  65000.0   44000.0
# 10    Paulo  South  67000.0   45000.0

# %%
sales_data.name.str.contains('William')
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# Name: name, dtype: bool

# %%
sales_data
# Out:
#        name region  sales  expenses
# 0   William   East  50000     42000
# 1      Emma      N  52000     43000
# 2     Sofia   East  90000      -999
# 3    Markus  South     -1     44000
# 4    Edward   West  42000     38000
# 5    Thomas   West  72000     39000
# 6     Ethan      S  49000     42000
# 7    Olivia   West     -1        -1
# 8      Arun   West  67000     39000
# 9     Anika   East  65000     44000
# 10    Paulo  South  67000     45000

# %%
print(r'first line\n last line')
# Out:
# first line\n last line

# %%
from sklearn.datasets import fetch_openml
from rich_dataframe import prettify

speed_dating = fetch_openml(name='SpeedDating', version=1)['frame']

table = prettify(speed_dating.head())
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">┏━━━┳━━━━━━━━━━┳━━━━━━┳━━━━━━━━┳━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━┓
# ┃<span style="font-weight: bold">   </span>┃<span style="font-weight: bold"> has_null </span>┃<span style="font-weight: bold"> wave </span>┃<span style="font-weight: bold"> gender </span>┃<span style="font-weight: bold">  age </span>┃<span style="font-weight: bold"> age_o </span>┃<span style="font-weight: bold"> d_age </span>┃<span style="font-weight: bold"> d_d_age </span>┃<span style="font-weight: bold"> race        </span>┃<span style="font-weight: bold"> race_o      </span>┃
# ┡━━━╇━━━━━━━━━━╇━━━━━━╇━━━━━━━━╇━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━┩
# │ 0 │        0 │  1.0 │ female │ 21.0 │  27.0 │   6.0 │   [4-6] │ Asian/Paci… │ European/C… │
# │   │          │      │        │      │       │       │         │ Islander/A… │             │
# │ 1 │        0 │  1.0 │ female │ 21.0 │  22.0 │   1.0 │   [0-1] │ Asian/Paci… │ European/C… │
# │   │          │      │        │      │       │       │         │ Islander/A… │             │
# │ 2 │        1 │  1.0 │ female │ 21.0 │  22.0 │   1.0 │   [0-1] │ Asian/Paci… │ Asian/Paci… │
# │   │          │      │        │      │       │       │         │ Islander/A… │ Islander/A… │
# │ 3 │        0 │  1.0 │ female │ 21.0 │  23.0 │   2.0 │   [2-3] │ Asian/Paci… │ European/C… │
# │   │          │      │        │      │       │       │         │ Islander/A… │             │
# │ 4 │        0 │  1.0 │ female │ 21.0 │  24.0 │   3.0 │   [2-3] │ Asian/Paci… │ Latino/His… │
# │   │          │      │        │      │       │       │         │ Islander/A… │ American    │
# └───┴──────────┴──────┴────────┴──────┴───────┴───────┴─────────┴─────────────┴─────────────┘
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
from rich_dataframe import prettify

var = {'a': 1, 'b': 3}
prettify(var)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">{</span><span style="color: #008000; text-decoration-color: #008000">'a'</span>: <span style="color: #000080; text-decoration-color: #000080; font-weight: bold">1</span>, <span style="color: #008000; text-decoration-color: #008000">'b'</span>: <span style="color: #000080; text-decoration-color: #000080; font-weight: bold">3</span><span style="font-weight: bold">}</span>
# </pre>

# %%
# @interact(a=1.1, b=1.1, c=1.1)
